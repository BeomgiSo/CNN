# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
from tensorflow.keras.preprocessing.image import load_img
from keras.preprocessing import image

from notebook.auth import passwd

# %%
foldernames = os.listdir('./data_preprocess')
categories = []
files = []
i = 0
#print(foldernames)
for k , folder in enumerate(foldernames):
    filenames = os.listdir("./data_preprocess/dog/" + folder)
    for file in filenames:
        files.append("./data_preprocess/dog/" + folder + "/" + file)
        categories.append(k)

df = pd.DataFrame({
    'filename': files,
    'category': categories
})
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/44/6_rc724s369980pjcph8pltr0000gp/T/ipykernel_1132/957562045.py in <module>
#       5 #print(foldernames)
#       6 for k , folder in enumerate(foldernames):
# ----> 7     filenames = os.listdir("./data_preprocess/dog/" + folder)
#       8     for file in filenames:
#       9         files.append("./data_preprocess/dog/" + folder + "/" + file)
#
# FileNotFoundError: [Errno 2] No such file or directory: './data_preprocess/dog/cat'

# %%
df.head()
# Out:
#                                 filename  category
# 0  ./data/Eskimo dog/n02109961_16718.jpg         0
# 1   ./data/Eskimo dog/n02109961_4369.jpg         0
# 2  ./data/Eskimo dog/n02109961_16095.jpg         0
# 3   ./data/Eskimo dog/n02109961_4157.jpg         0
# 4   ./data/Eskimo dog/n02109961_2532.jpg         0

# %%
df.tail()
# Out:
#                                            filename  category
# 26077   ./data/Australian terrier/n02096294_484.jpg       126
# 26078  ./data/Australian terrier/n02096294_4440.jpg       126
# 26079  ./data/Australian terrier/n02096294_5602.jpg       126
# 26080  ./data/Australian terrier/n02096294_1470.jpg       126
# 26081  ./data/Australian terrier/n02096294_8124.jpg       126

# %%
# 카테고리에 따른 데이터 갯수
df['category'].value_counts()

CountStatus = pd.value_counts(data['col'].values, sort=True)
CountStatus.plot.bar()
CountStatus.plot.bar(grid=True, figsize=(10,8), fontsize=15)  # figsize, fontsize 조정
# Out:
# 19     419
# 74     418
# 41     413
# 17     410
# 48     400
#       ...
# 43     150
# 37     150
# 63     150
# 23     149
# 124    148
# Name: category, Length: 127, dtype: int64

# %%
CountStatus = pd.value_counts(df['category'].values)
CountStatus.plot.bar()
CountStatus.plot.bar(grid=True, figsize=(20,10), fontsize=8) 
# count 갯수의 threshold 값설정 기준 잡기
# Out:
# <AxesSubplot:>

# %%
dog_category=df['category'].max()
# categoty 변경
n=20
check_imge=df.loc[df['category']==3]
check_imge_random = check_imge.sample(n)
a=check_imge_random.iloc[1]
a['filename']
# Out:
# './data/Irish terrier/n02093991_2518.jpg'

# %%
dog_category=df['category'].max()
# categoty 변경
n=20
check_imge=df.loc[df['category']==2]
check_imge_random = check_imge.sample(n)
a=check_imge_random.iloc[1]
a['filename']

random_images = []
random_labels = []

plt.figure(figsize=(16,16))
for i in range(len(check_imge_random)):
     random_image = check_imge_random.iloc[i]
     img = load_img(random_image['filename'])
     ax1 = plt.subplot(n//5,5,i+1)
     plt.imshow(img)
     plt.axis('off')
     img_tensor = image.img_to_array(img)
     img_tensor = img_tensor.shape[:2]
     ax1.set_title(f"{img_tensor}")
